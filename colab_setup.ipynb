# %% [markdown]
# # ASAN Macro – Run in Google Colab
#
# This notebook clones the ASAN Macro repo, installs dependencies, and runs the trade sentiment report.
#
# **You need an API key:** Colab cannot run local Ollama. Use **Gemini** (free at [aistudio.google.com/apikey](https://aistudio.google.com/apikey)) or **OpenAI**.

# %%
# 1. Clone the repository (run once per session)
# !git clone https://github.com/Arnav504/ASAN_AI_Project.git
# %cd ASAN_AI_Project

# %%
# 2. Install dependencies
# !pip install -q -r requirements.txt

# %%
# 3. Set your API key (choose one)
# Option A: Gemini (free tier) – get key at https://aistudio.google.com/apikey
import os
os.environ["GEMINI_API_KEY"] = "YOUR_GEMINI_API_KEY"  # Replace with your key

# Option B: Or use OpenAI instead
# os.environ["OPENAI_API_KEY"] = "sk-..."

# Optional: use Colab's "Secrets" so you don't paste the key in the notebook
# from google.colab import userdata
# os.environ["GEMINI_API_KEY"] = userdata.get("GEMINI_API_KEY")

# %%
# 4. Run the agent and generate report
# !python main.py -q "BRICS" -o report.txt

# %%
# 5. Display the report
with open("report.txt", "r") as f:
    print(f.read())

# %% [markdown]
# ## Other options
#
# - **Different query:** `!python main.py -q "US-China electronics" -o report.txt`
# - **HTML output:** `!python main.py -q "BRICS" -o report.html -f html`
# - **JSON output:** `!python main.py -q "BRICS" -o report.json -f json`
# - **LinkedIn format:** `!python main.py -o report.txt -f linkedin`
